# %%
test_string = "hello! こんにちは!"
utf8_encode = test_string.encode("utf-8")
print(utf8_encode)
print(type(utf8_encode))
print(list(utf8_encode))
print(len(test_string))
print(len(utf8_encode))
print(utf8_encode.decode("utf-8"))
# Out:
# b'hello! \xe3\x81\x93\xe3\x82\x93\xe3\x81\xab\xe3\x81\xa1\xe3\x81\xaf!'
# <class 'bytes'>
# [104, 101, 108, 108, 111, 33, 32, 227, 129, 147, 227, 130, 147, 227, 129, 171, 227, 129, 161, 227, 129, 175, 33]
# 13
# 23
# hello! こんにちは!

# %%
def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
 return "".join(bytestring.decode("utf-8"))

# %%
decode_utf8_bytes_to_str_wrong("Ігор".encode("utf-8"))
# Out:
# 'Ігор'

# %%
print(b'\xc0\xaf'.decode())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(b'\xc0\xaf'.decode())
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc0 in position 0: invalid start byte

# %%
import regex as re
PAT = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""

# %%
file_path = "C:\\Users\\Ihor\\\Desktop\\Stanford_LLM\\assignment1-basics\\data\\TinyStoriesV2-GPT4-valid.txt"
with open(file_path, "r", encoding="utf-8") as file:
  data = file.read()
re.findall(PAT, data)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Ihor\AppData\Local\Temp\ipykernel_13916\3004448025.py:1: SyntaxWarning: invalid escape sequence '\D'
#   file_path = "C:\\Users\\Ihor\\\Desktop\\Stanford_LLM\\assignment1-basics\\data\\TinyStoriesV2-GPT4-valid.txt"
# ['u',
#  ' don',
#  "'t",
#  ' have',
#  ' to',
#  ' be',
#  ' scared',
#  ' of',
#  ' the',
#  ' loud',
#  ' dog',
#  ',',
#  ' I',
#  "'ll",
#  ' protect',
#  ' you',
#  '".',
#  ' The',
#  ' mole',
#  ' felt',
#  ' so',
#  ' safe',
#  ' with',
#  ' the',
#  ' little',
#  ' girl',
#  '.',
#  ' She',
#  ' was',
#  ' very',
#  ' kind',
#  ' and',
#  ' the',
#  ' mole',
#  ' soon',
#  ' came',
#  ' to',
#  ' trust',
#  ' her',
#  '.',
#  ' He',
#  ' leaned',
#  ' against',
#  ' her',
#  ' and',
#  ' she',
#  ' kept',
#  ' him',
#  ' safe',
#  '.',
#  ' The',
#  ' mole',
#  ' had',
#  ' found',
#  ' his',
#  ' best',
#  ' friend',
#  '.',
#  '\n',
#  '<|',
# ...
